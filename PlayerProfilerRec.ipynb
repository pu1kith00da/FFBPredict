# %%
import pandas as pd
import requests
from google.colab import drive
import warnings
warnings.filterwarnings('ignore')

# %%
# Get player IDs
url = 'https://www.playerprofiler.com/api/v1/players'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36'}
jsonData = requests.get(url, headers=headers).json()
players = jsonData['data']['Players']

wrs_tes = [player for player in players if player.get('Position') in ['WR', 'TE']]

# %%
rows = []
for player in wrs_tes:
    row = {}
    #print ('Aquired: %s' %player['Full Name'])
    url = 'https://www.playerprofiler.com/wp-admin/admin-ajax.php'
    payload = {
    'action': 'playerprofiler_api',
    'endpoint': '/player/%s' %player['Player_ID']}
    season = '2020'

    jsonData = requests.get(url, headers=headers, params=payload).json()
    if 'Performance Metrics' in jsonData['data']['Player'].keys():
        if season in jsonData['data']['Player']['Performance Metrics'].keys():
            data = jsonData['data']['Player']['Performance Metrics'][season]
        else:
            continue
    else:
        continue

    for each in [data, player]:
        row.update(each)
    rows.append(row)

df = pd.DataFrame(rows)

# %%
df
# Out:
#     Season Games Games Rank Air Yards Air Yards Per Game Air Yards Rank  \
# 0     2020    16          1      1161            72.5625              2
# 1     2020    15         40       377            25.1333             26
# 2     2020    16          1      1490             93.125              7
# 3     2020    16          1       988              61.75             36
# 4     2020    14         82      1130            80.7143             31
# ..     ...   ...        ...       ...                ...            ...
# 384   2020     5        114         0                  0           None
# 385   2020     2        223         0                  0           None
# 386   2020     5        114        19                3.8           None
# 387   2020     1        237         0                  0           None
# 388   2020     1        135         0                  0           None
#
#     Air Yards Share Air Yards Share Rank Average Target Distance  \
# 0           26.0372                    2                  8.0069
# 1           11.0752                   24                     5.8
# 2           37.1386                    8                   11.92
# 3           21.6572                   56                  8.9009
# 4           34.3883                   11                 10.6604
# ..              ...                  ...                     ...
# 384               0                 None                       0
# 385               0                 None                       0
# 386          1.6919                 None                       0
# 387               0                 None                       0
# 388               0                 None                       0
#
#     Average Target Distance Rank  ... Expected Passing Yards  \
# 0                             13  ...                    NaN
# 1                             38  ...                    NaN
# 2                             37  ...                    NaN
# 3                             76  ...                    NaN
# 4                             49  ...                    NaN
# ..                           ...  ...                    ...
# 384                         None  ...                    NaN
# 385                         None  ...                    NaN
# 386                         None  ...                    NaN
# 387                         None  ...                    NaN
# 388                         None  ...                    NaN
#
#     Expected Passing Touchdowns Expected Rushing Yards Passing Interceptions  \
# 0                           NaN                    NaN                   NaN
# 1                           NaN                    NaN                   NaN
# 2                           NaN                    NaN                   NaN
# 3                           NaN                    NaN                   NaN
# 4                           NaN                    NaN                   NaN
# ..                          ...                    ...                   ...
# 384                         NaN                    NaN                   NaN
# 385                         NaN                    NaN                   NaN
# 386                         NaN                    NaN                   NaN
# 387                         NaN                    NaN                   NaN
# 388                         NaN                    NaN                   NaN
#
#     Passing Interceptions Rank Passing Air Yards Passing Air Yards Rank  \
# 0                          NaN               NaN                    NaN
# 1                          NaN               NaN                    NaN
# 2                          NaN               NaN                    NaN
# 3                          NaN               NaN                    NaN
# 4                          NaN               NaN                    NaN
# ..                         ...               ...                    ...
# 384                        NaN               NaN                    NaN
# 385                        NaN               NaN                    NaN
# 386                        NaN               NaN                    NaN
# 387                        NaN               NaN                    NaN
# 388                        NaN               NaN                    NaN
#
#     Passing Air Yards Per Game Passing Air Yards Per Attempt  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
# ..                         ...                           ...
# 384                        NaN                           NaN
# 385                        NaN                           NaN
# 386                        NaN                           NaN
# 387                        NaN                           NaN
# 388                        NaN                           NaN
#
#     Passing Air Yards Per Attempt Rank
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 384                                NaN
# 385                                NaN
# 386                                NaN
# 387                                NaN
# 388                                NaN
#
# [389 rows x 358 columns]

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.to_csv('/content/drive/My Drive/PlayerProfilerREC2020.csv', index=False)
