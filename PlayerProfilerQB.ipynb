# %%
import pandas as pd
import requests
from google.colab import drive
import warnings
warnings.filterwarnings('ignore')

# %%
# Get player IDs
url = 'https://www.playerprofiler.com/api/v1/players'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36'}
jsonData = requests.get(url, headers=headers).json()
players = jsonData['data']['Players']


qbs = [player for player in players if player.get('Position') == 'QB']

# %%
rows = []
for player in qbs:
    row = {}
    #print ('Aquired: %s' %player['Full Name'])
    url = 'https://www.playerprofiler.com/wp-admin/admin-ajax.php'
    payload = {
    'action': 'playerprofiler_api',
    'endpoint': '/player/%s' %player['Player_ID']}
    season = '2020'

    jsonData = requests.get(url, headers=headers, params=payload).json()
    if 'Performance Metrics' in jsonData['data']['Player'].keys():
        if season in jsonData['data']['Player']['Performance Metrics'].keys():
            data = jsonData['data']['Player']['Performance Metrics'][season]
        else:
            continue
    else:
        continue

    for each in [data, player]:
        row.update(each)
    rows.append(row)

df = pd.DataFrame(rows)

# %%
df
# Out:
#    Season Games Games Rank Accuracy Rating Accuracy Rating Rank  \
# 0    2020    15         15          7.4261                   15
# 1    2020    15         15          6.3433                 None
# 2    2020    15         15          7.1143                   28
# 3    2020    16          1          7.4226                   16
# 4    2020    16          1          7.4716                   13
# ..    ...   ...        ...             ...                  ...
# 76   2020     1         69          6.9444                 None
# 77   2020     4         51          7.0982                 None
# 78   2020     5         43          6.9531                 None
# 79   2020     2         64          5.5556                 None
# 80   2020     1         69            3.75                 None
#
#    Adjusted Attempts Adjusted Yards Per Attempt  \
# 0                546                     8.5738
# 1                131                     6.2174
# 2                342                     7.0914
# 3                526                     8.0836
# 4                512                     6.7538
# ..               ...                        ...
# 76                 8                    -0.9286
# 77                48                     2.7167
# 78                30                     2.2927
# 79                 8                         11
# 80                 4                        3.6
#
#    Adjusted Yards Per Attempt Rank Air Yards Air Yards Rank  ...  \
# 0                                3      4865              4  ...
# 1                             None      1195             39  ...
# 2                               16      3215             23  ...
# 3                                5      4871              3  ...
# 4                               20      4292             10  ...
# ..                             ...       ...            ...  ...
# 76                            None        94             67  ...
# 77                            None       571             47  ...
# 78                            None       327             54  ...
# 79                            None        77             69  ...
# 80                            None        43             73  ...
#
#    Formation Adjusted Yards Per Route Run Rank Yards Per Team Pass Attempt  \
# 0                                          NaN                         NaN
# 1                                          NaN                         NaN
# 2                                          NaN                         NaN
# 3                                          NaN                         NaN
# 4                                          NaN                         NaN
# ..                                         ...                         ...
# 76                                         NaN                         NaN
# 77                                         NaN                         NaN
# 78                                         NaN                         NaN
# 79                                         NaN                         NaN
# 80                                         NaN                         NaN
#
#    Yards Per Team Pass Attempt Rank Receiving Air Yards  \
# 0                               NaN                 NaN
# 1                               NaN                 NaN
# 2                               NaN                 NaN
# 3                               NaN                 NaN
# 4                               NaN                 NaN
# ..                              ...                 ...
# 76                              NaN                 NaN
# 77                              NaN                 NaN
# 78                              NaN                 NaN
# 79                              NaN                 NaN
# 80                              NaN                 NaN
#
#    Receiving Air Yards Rank Receiving Air Yards Per Game  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
# ..                      ...                          ...
# 76                      NaN                          NaN
# 77                      NaN                          NaN
# 78                      NaN                          NaN
# 79                      NaN                          NaN
# 80                      NaN                          NaN
#
#    Receiving Air Yards Share Receiving Air Yards Share Rank Receiving Burns  \
# 0                        NaN                            NaN             NaN
# 1                        NaN                            NaN             NaN
# 2                        NaN                            NaN             NaN
# 3                        NaN                            NaN             NaN
# 4                        NaN                            NaN             NaN
# ..                       ...                            ...             ...
# 76                       NaN                            NaN             NaN
# 77                       NaN                            NaN             NaN
# 78                       NaN                            NaN             NaN
# 79                       NaN                            NaN             NaN
# 80                       NaN                            NaN             NaN
#
#    Receiving Burn Rate
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 76                 NaN
# 77                 NaN
# 78                 NaN
# 79                 NaN
# 80                 NaN
#
# [81 rows x 358 columns]

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.to_csv('/content/drive/My Drive/PlayerProfilerQB2020.csv', index=False)
