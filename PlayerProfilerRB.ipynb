# %%
import pandas as pd
import requests
from google.colab import drive
import warnings
warnings.filterwarnings('ignore')

# %%
# Get player IDs
url = 'https://www.playerprofiler.com/api/v1/players'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.83 Safari/537.36'}
jsonData = requests.get(url, headers=headers).json()
players = jsonData['data']['Players']


rbs = [player for player in players if player.get('Position') == 'RB']

# %%
rows = []
for player in rbs:
    row = {}
    #print ('Aquired: %s' %player['Full Name'])
    url = 'https://www.playerprofiler.com/wp-admin/admin-ajax.php'
    payload = {
    'action': 'playerprofiler_api',
    'endpoint': '/player/%s' %player['Player_ID']}
    season = '2020'

    jsonData = requests.get(url, headers=headers, params=payload).json()
    if 'Performance Metrics' in jsonData['data']['Player'].keys():
        if season in jsonData['data']['Player']['Performance Metrics'].keys():
            data = jsonData['data']['Player']['Performance Metrics'][season]
        else:
            continue
    else:
        continue

    for each in [data, player]:
        row.update(each)
    rows.append(row)

df = pd.DataFrame(rows)

# %%
df
# Out:
#              FullName Season Games Games Rank Average Defenders In The Box  \
# 0     Jonathan Taylor   2020    15         28                       6.9181
# 1       D'Andre Swift   2020    13         62                       6.9561
# 2      Saquon Barkley   2020     2        144                       6.2105
# 3       Derrick Henry   2020    16          1                       7.1323
# 4        Alvin Kamara   2020    15         28                       7.0428
# ..                ...    ...   ...        ...                          ...
# 167       Gabe Nabers   2020     8         86                          7.5
# 168     Jason Cabinda   2020     4        125                            7
# 169        Jeremy Cox   2020     7        114                           NA
# 170  Khari Blasingame   2020    15         28                           NA
# 171       Mike Burton   2020     6        103                         7.43
#
#     Average Defenders In The Box Rank Base Front Carry Rate  \
# 0                                  27               43.1034
# 1                                  24               41.2281
# 2                                None               31.5789
# 3                                  15               43.9153
# 4                                  19               41.1765
# ..                                ...                   ...
# 167                                 -                    50
# 168                                 -                   100
# 169                              None                    NA
# 170                              None                    NA
# 171                                 -                  28.6
#
#     Base Front Carry Rate Rank Base Front Yards Per Carry  \
# 0                           21                       4.65
# 1                           28                      4.383
# 2                         None                     4.3333
# 3                           17                     5.6325
# 4                           29                     3.8701
# ..                         ...                        ...
# 167                         25                          3
# 168                          1                          0
# 169                       None                          0
# 170                       None                          0
# 171                        118                          1
#
#     Base Front Yards Per Carry Rank  ... Receiving Burns Receiving Burn Rate  \
# 0                                25  ...             NaN                 NaN
# 1                                30  ...             NaN                 NaN
# 2                              None  ...             NaN                 NaN
# 3                                 7  ...             NaN                 NaN
# 4                                43  ...             NaN                 NaN
# ..                              ...  ...             ...                 ...
# 167                               -  ...             NaN                 NaN
# 168                               -  ...             NaN                 NaN
# 169                            None  ...             NaN                 NaN
# 170                            None  ...             NaN                 NaN
# 171                               -  ...             NaN                 NaN
#
#     Expected Points Added (EPA) Expected Points Added (EPA) Rank  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
# ..                          ...                              ...
# 167                        0.42                              114
# 168                        -9.2                              116
# 169                         NaN                              NaN
# 170                         NaN                              NaN
# 171                        3.09                              136
#
#     Run Blocking Efficiency Run Blocking Efficiency Rank  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
# ..                      ...                          ...
# 167                                                  129
# 168                                                  101
# 169                     NaN                          NaN
# 170                     NaN                          NaN
# 171                                                  140
#
#     Snap weighted Game Script Snap weighted Game Script Rank Team Run Plays  \
# 0                         NaN                            NaN            NaN
# 1                         NaN                            NaN            NaN
# 2                         NaN                            NaN            NaN
# 3                         NaN                            NaN            NaN
# 4                         NaN                            NaN            NaN
# ..                        ...                            ...            ...
# 167                     -2.06                             17           29.1
# 168                     -6.02                             29           22.9
# 169                       NaN                            NaN            NaN
# 170                       NaN                            NaN            NaN
# 171                      2.73                              4           30.8
#
#     Team Run Plays Rank
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 167                   9
# 168                  29
# 169                 NaN
# 170                 NaN
# 171                   4
#
# [172 rows x 321 columns]

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.to_csv('/content/drive/My Drive/PlayerProfilerRB2020.csv', index=False)
